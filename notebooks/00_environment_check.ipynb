# %%
# %% [markdown]
# # 🔧 Environment Verification
# *Run this BEFORE any analysis to confirm dependencies*
# 
# **Purpose**: Validate local + Colab environments match requirements.txt
# **Date**: $(date)
# **Author**: Anuj Chaudhary

# %% [code]
# INSTALL EXACT VERSIONS IN COLAB (match requirements.txt)
# !pip install -q \
#     pandas==2.0.3 \
#     numpy==1.24.3 \
#     scikit-learn==1.3.0 \
#     xgboost==1.7.6 \
#     shap==0.44.1 \
#     matplotlib==3.7.2 \
#     seaborn==0.13.0 \
#     plotly==5.17.0 \
#     imbalanced-learn==0.11.0

# %% [code]
# Verify core imports and versions
import sys
print(f"✅ Python version: {sys.version.split()[0]}")

# Core libraries with version checks
import pandas as pd; print(f"✅ pandas: {pd.__version__}")
import numpy as np; print(f"✅ numpy: {np.__version__}")
import sklearn; print(f"✅ scikit-learn: {sklearn.__version__}")
import xgboost; print(f"✅ xgboost: {xgboost.__version__}")
import shap; print(f"✅ shap: {shap.__version__}")
import matplotlib; print(f"✅ matplotlib: {matplotlib.__version__}")
import seaborn as sns; print(f"✅ seaborn: {sns.__version__}")
import plotly; print(f"✅ plotly: {plotly.__version__}")

print("\n🎉 All dependencies loaded successfully!")
# Out:
# ✅ Python version: 3.11.9
# ✅ pandas: 2.3.3
# ✅ numpy: 1.26.4
# ✅ scikit-learn: 1.8.0
# ✅ xgboost: 1.7.6
# ✅ shap: 0.44.1
# ✅ matplotlib: 3.10.9
# ✅ seaborn: 0.13.2
# ✅ plotly: 5.24.1
#
# 🎉 All dependencies loaded successfully!
